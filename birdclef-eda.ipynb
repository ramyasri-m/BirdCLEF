# %%
import pandas as pd

# Load the metadata file
metadata_path = '/kaggle/input/birdclef-2022/train_metadata.csv'
metadata_df = pd.read_csv(metadata_path)

# Display the total number of samples
total_samples = len(metadata_df)
print(f"Total number of samples: {total_samples}")

# Display different ratings present and the number of samples per each rating
ratings_count = metadata_df['rating'].value_counts().sort_index()
print("\nNumber of samples per each rating:")
print(ratings_count)
# Out:
# Total number of samples: 14852
#
# Number of samples per each rating:
# rating
# 0.0     570
# 0.5      30
# 1.0     155
# 1.5     152
# 2.0     575
# 2.5     724
# 3.0    1957
# 3.5    1765
# 4.0    3974
# 4.5    1632
# 5.0    3318
# Name: count, dtype: int64

# %%
import pandas as pd

# Load the taxonomy file
taxonomy_path = '/kaggle/input/birdclef-2022/eBird_Taxonomy_v2021.csv'
taxonomy_df = pd.read_csv(taxonomy_path)

# List of columns to analyze
columns_to_analyze = ['CATEGORY', 'SPECIES_CODE', 'PRIMARY_COM_NAME', 'SCI_NAME', 'ORDER1', 'FAMILY', 'SPECIES_GROUP']

# Function to analyze each column
def analyze_column(df, column_name):
    print(f"\nColumn: {column_name}")
    
    # Total number of unique values
    unique_values = df[column_name].nunique()
    print(f"Total number of unique values: {unique_values}")
    
    # Number of missing values
    missing_values = df[column_name].isnull().sum()
    print(f"Number of missing values: {missing_values}")
    
    # Count of occurrences for each unique value
    value_counts = df[column_name].value_counts()
    print(f"\nCount of occurrences for each unique value:\n{value_counts}")

# Analyze each column in the list
for column in columns_to_analyze:
    analyze_column(taxonomy_df, column)
# Out:
# Column: CATEGORY
# Total number of unique values: 8
# Number of missing values: 0
#
# Count of occurrences for each unique value:
# CATEGORY
# species       10824
# issf           3761
# slash           788
# spuh            666
# hybrid          545
# form            120
# intergrade       34
# domestic         15
# Name: count, dtype: int64
#
# Column: SPECIES_CODE
# Total number of unique values: 16753
# Number of missing values: 0
#
# Count of occurrences for each unique value:
# SPECIES_CODE
# ostric2    1
# rolcis2    1
# rolcis4    1
# rolcis3    1
# borcis1    1
#           ..
# grebar3    1
# linbar1    1
# y00399     1
# brhbar1    1
# bird1      1
# Name: count, Length: 16753, dtype: int64
#
# Column: PRIMARY_COM_NAME
# Total number of unique values: 16753
# Number of missing values: 0
#
# Count of occurrences for each unique value:
# PRIMARY_COM_NAME
# Common Ostrich                    1
# Rock-loving Cisticola             1
# Rock-loving Cisticola (Huambo)    1
# Rock-loving Cisticola (Lazy)      1
# Boran Cisticola                   1
#                                  ..
# Green-eared Barbet                1
# Lineated Barbet                   1
# Green-eared/Lineated Barbet       1
# Brown-headed Barbet               1
# bird sp.                          1
# Name: count, Length: 16753, dtype: int64
#
# Column: SCI_NAME
# Total number of unique values: 16753
# Number of missing values: 0
#
# Count of occurrences for each unique value:
# SCI_NAME
# Struthio camelus                       1
# Cisticola aberrans                     1
# Cisticola aberrans bailunduensis       1
# Cisticola aberrans [aberrans Group]    1
# Cisticola bodessa                      1
#                                       ..
# Psilopogon faiostrictus                1
# Psilopogon lineatus                    1
# Psilopogon faiostrictus/lineatus       1
# Psilopogon zeylanicus                  1
# Aves sp.                               1
# Name: count, Length: 16753, dtype: int64
#
# Column: ORDER1
# Total number of unique values: 41
# Number of missing values: 2
#
# Count of occurrences for each unique value:
# ORDER1
# Passeriformes          9935
# Caprimulgiformes        870
# Charadriiformes         667
# Piciformes              635
# Psittaciformes          571
# Columbiformes           469
# Anseriformes            424
# Galliformes             417
# Accipitriformes         414
# Strigiformes            385
# Gruiformes              284
# Coraciiformes           268
# Procellariiformes       234
# Cuculiformes            215
# Pelecaniformes          196
# Falconiformes           110
# Bucerotiformes          105
# Suliformes               94
# Galbuliformes            77
# Trogoniformes            67
# Tinamiformes             58
# Musophagiformes          43
# Otidiformes              34
# Podicipediformes         32
# Ciconiiformes            26
# Pterocliformes           24
# Sphenisciformes          22
# Cathartiformes           12
# Phaethontiformes         11
# Phoenicopteriformes       9
# Gaviiformes               8
# Apterygiformes            8
# Coliiformes               7
# Rheiformes                4
# Casuariiformes            4
# Mesitornithiformes        3
# Struthioniformes          3
# Eurypygiformes            2
# Cariamiformes             2
# Leptosomiformes           1
# Opisthocomiformes         1
# Name: count, dtype: int64
#
# Column: FAMILY
# Total number of unique values: 249
# Number of missing values: 13
#
# Count of occurrences for each unique value:
# FAMILY
# Tyrannidae (Tyrant Flycatchers)             658
# Thraupidae (Tanagers and Allies)            544
# Trochilidae (Hummingbirds)                  533
# Muscicapidae (Old World Flycatchers)        529
# Furnariidae (Ovenbirds and Woodcreepers)    495
#                                            ...
# Hypocoliidae (Hypocolius)                     1
# Sagittariidae (Secretarybird)                 1
# Platylophidae (Crested Shrikejay)             1
# Peucedramidae (Olive Warbler)                 1
# Donacobiidae (Donacobius)                     1
# Name: count, Length: 249, dtype: int64
#
# Column: SPECIES_GROUP
# Total number of unique values: 216
# Number of missing values: 16537
#
# Count of occurrences for each unique value:
# SPECIES_GROUP
# Ostriches              1
# African Warblers       1
# Australasian Robins    1
# Rockfowl               1
# Rockjumpers            1
#                       ..
# Asities                1
# Old World Pittas       1
# Antbirds               1
# Crescentchests         1
# Others                 1
# Name: count, Length: 216, dtype: int64

# %%
import pandas as pd

# Load the metadata file
metadata_path = '/kaggle/input/birdclef-2022/train_metadata.csv'
metadata_df = pd.read_csv(metadata_path)

# Filter the DataFrame to include only samples with rating >= 3
filtered_metadata_df = metadata_df[metadata_df['rating'] >= 3]

# Display the total number of filtered samples
filtered_samples = len(filtered_metadata_df)
print(f"Total number of samples with rating >= 3: {filtered_samples}")

# Display different ratings present in the filtered DataFrame and the number of samples per each rating
filtered_ratings_count = filtered_metadata_df['rating'].value_counts().sort_index()
print("\nNumber of samples per each rating (rating >= 3):")
print(filtered_ratings_count)
# Out:
# Total number of samples with rating >= 3: 12646
#
# Number of samples per each rating (rating >= 3):
# rating
# 3.0    1957
# 3.5    1765
# 4.0    3974
# 4.5    1632
# 5.0    3318
# Name: count, dtype: int64

# %%
# List of columns to analyze
columns_to_analyze = ['primary_label', 'secondary_labels', 'type']

# Function to analyze each column
def analyze_column(df, column_name):
    print(f"\nColumn: {column_name}")
    
    # Total number of unique values
    unique_values = df[column_name].nunique()
    print(f"Total number of unique values: {unique_values}")
    
    # Number of missing values
    missing_values = df[column_name].isnull().sum()
    print(f"Number of missing values: {missing_values}")
    
    # Count of occurrences for each unique value
    value_counts = df[column_name].value_counts()
    print(f"\nCount of occurrences for each unique value:\n{value_counts}")

# Analyze each column in the list
for column in columns_to_analyze:
    analyze_column(filtered_metadata_df, column)
# Out:
# Column: primary_label
# Total number of unique values: 151
# Number of missing values: 0
#
# Count of occurrences for each unique value:
# primary_label
# mallar3    441
# norcar     441
# skylar     427
# brnowl     421
# bcnher     400
#           ...
# akikik       2
# layalb       2
# hawpet1      2
# hawhaw       2
# maupar       1
# Name: count, Length: 151, dtype: int64
#
# Column: secondary_labels
# Total number of unique values: 249
# Number of missing values: 0
#
# Count of occurrences for each unique value:
# secondary_labels
# []                                                 11451
# ['houspa']                                            81
# ['mallar3']                                           59
# ['moudov']                                            58
# ['houfin']                                            43
#                                                    ...
# ['comgal1', 'lesyel']                                  1
# ['cacgoo1']                                            1
# ['redjun', 'wesmea']                                   1
# ['apapan', 'hawama', 'iiwi', 'omao', 'warwhe1']        1
# ['commyn', 'spodov']                                   1
# Name: count, Length: 249, dtype: int64
#
# Column: type
# Total number of unique values: 1051
# Number of missing values: 0
#
# Count of occurrences for each unique value:
# type
# ['call']                                                               3347
# ['song']                                                               1691
# ['flight call']                                                        1231
# ['nocturnal flight call']                                               669
# ['call', 'song']                                                        353
#                                                                        ...
# ['call', 'male', 'nocturnal flight call']                                 1
# ['female', 'life stage uncertain', 'male', 'nocturnal flight call']       1
# ['bill snaps', 'breeding call (I presume)']                               1
# ['display call']                                                          1
# ['adult', 'call', 'duet', 'sex uncertain']                                1
# Name: count, Length: 1051, dtype: int64

# %%
from collections import Counter

# List of columns to analyze that contain lists as strings
columns_to_analyze = ['secondary_labels', 'type']

# Function to analyze each column with individual string components
def analyze_column_individual(df, column_name):
    print(f"\nAnalyzing individual values within the column: {column_name}")
    
    # Initialize a Counter to count each unique item across all entries
    item_counter = Counter()
    
    # Iterate over each entry in the column
    for entry in df[column_name].dropna():
        # Convert the string to a list (assuming entries are in the format "['item1', 'item2', ...]")
        items = eval(entry)  # use `eval` with caution; assumes consistent, trusted data format
        # Update the counter with items in the list
        item_counter.update(items)
    
    # Print total unique items and counts for each
    unique_items = len(item_counter)
    print(f"Total number of unique items: {unique_items}")
    print(f"\nCount of occurrences for each unique item:\n{item_counter}")

# Analyze each column in the list
for column in columns_to_analyze:
    analyze_column_individual(filtered_metadata_df, column)
# Out:
# Analyzing individual values within the column: secondary_labels
# Total number of unique items: 100
#
# Count of occurrences for each unique item:
# Counter({'moudov': 127, 'houspa': 106, 'houfin': 100, 'mallar3': 82, 'gamqua': 75, 'apapan': 67, 'normoc': 62, 'norcar': 61, 'wesmea': 61, 'cangoo': 56, 'iiwi': 42, 'skylar': 41, 'warwhe1': 40, 'bknsti': 34, 'hawama': 32, 'gnwtea': 30, 'zebdov': 28, 'comgal1': 26, 'commyn': 24, 'dunlin': 22, 'arcter': 19, 'rinphe': 18, 'eurwig': 16, 'lesyel': 15, 'omao': 14, 'laugul': 14, 'redjun': 13, 'belkin1': 13, 'amewig': 13, 'rorpar': 13, 'leasan': 12, 'ribgul': 12, 'gadwal': 12, 'calqua': 12, 'norsho': 11, 'pibgre': 11, 'bkbplo': 11, 'lobdow': 11, 'sora': 9, 'spodov': 9, 'jabwar': 9, 'glwgul': 9, 'osprey': 8, 'rudtur': 8, 'norpin': 8, 'wiltur': 8, 'grbher3': 7, 'rocpig': 6, 'leater1': 5, 'snogoo': 5, 'caster1': 5, 'comwax': 5, 'bongul': 5, 'bcnher': 4, 'categr': 4, 'semplo': 4, 'cacgoo1': 4, 'fragul': 4, 'pecsan': 4, 'kauama': 3, 'aniani': 3, 'brant': 3, 'sposan': 3, 'gwfgoo': 3, 'brnowl': 3, 'whiter': 3, 'nutman': 3, 'oahama': 3, 'akiapo': 2, 'elepai': 2, 'hawcre': 2, 'saffin': 2, 'comsan': 2, 'hawgoo': 2, 'hawcoo': 2, 'sooshe': 2, 'buwtea': 2, 'sooter1': 2, 'sander': 2, 'hoomer': 2, 'refboo': 2, 'wessan': 2, 'redpha1': 2, 'pomjae': 2, 'blknod': 2, 'compea': 2, 'redava': 1, 'akepa1': 1, 'akikik': 1, 'blkfra': 1, 'brtcur': 1, 'brnnod': 1, 'rettro': 1, 'chukar': 1, 'bkwpet': 1, 'whfibi': 1, 'cintea': 1, 'lessca': 1, 'reccar': 1, 'yefcan': 1})
#
# Analyzing individual values within the column: type
# Total number of unique items: 572
#
# Count of occurrences for each unique item:
# Counter({'call': 6189, 'song': 3205, 'flight call': 2657, 'male': 1503, 'nocturnal flight call': 1317, 'adult': 1299, 'sex uncertain': 966, 'female': 739, 'alarm call': 720, 'juvenile': 408, 'life stage uncertain': 302, 'begging call': 281, 'uncertain': 56, 'calls': 37, 'subsong': 34, 'wingbeats': 31, 'Song': 30, 'mimicry/imitation': 30, 'aberrant': 26, 'hatchling or nestling': 25, 'social calls': 24, 'wing beats': 23, 'duet': 22, 'flight calls': 20, 'wing noise': 20, 'Call': 16, 'interaction calls': 16, 'wing-clapping': 16, 'various calls': 15, 'flight song': 15, 'short calls': 14, 'Nocturnal call': 13, 'wings': 12, 'display': 12, 'long call': 11, 'Nocturnal Flight Call': 9, 'NFC': 9, 'rolled calls': 9, 'pair interaction calls': 9, 'nocturnal flightcall': 8, 'nocturnal': 8, 'pair contact calls': 8, 'Nocturnal flight call': 7, 'contact calls': 7, 'distraction display': 7, '': 6, 'Nocturnal rooting site': 6, 'advertising call': 6, 'dawn song': 6, 'wing sounds': 5, 'interaction call': 5, 'Short calls': 5, 'flock calls': 5, 'excitement call': 5, 'Wing noise': 5, 'short call': 5, 'Whinny': 5, 'low rattle': 4, 'take-off and flight calls': 4, 'bird in hand': 4, 'contact call': 4, 'single bird flying off': 4, 'social call': 4, 'canto': 4, 'song in flight': 4, 'Nocturnal Flight call': 4, 'Screech': 4, 'flushed call': 4, 'autumn call': 4, 'wing flutter': 4, 'chatting': 4, 'Flight song': 4, 'whinny': 4, 'churts and sputters': 4, 'Alarm call': 3, 'night flight call': 3, 'Flight call': 3, 'Wing flapping': 3, 'wing whir': 3, 'series of calls': 3, 'anthropogenic': 3, 'whistle call': 3, 'display call': 3, 'Chirp': 3, 'wing flapping': 3, 'quiet-call': 3, 'Wingbeats': 3, 'landing on the water': 3, 'Calls': 3, 'nest coo': 3, 'scold': 3, 'Wingbeat': 3, 'FEEDING PAIR': 3, 'peweep': 3, 'individual call': 3, 'per-weep': 3, 'traffic': 2, 'Whi-Whee-Whew': 2, 'female call': 2, 'male call': 2, 'courtship call': 2, 'attack': 2, 'no': 2, 'alarm and flight calls': 2, 'agitated calls': 2, 'calls in flight': 2, 'Flock vocalizations': 2, 'various calls from a flock': 2, 'call,flight call,begging call': 2, 'single calls': 2, 'aggitated call': 2, 'whinny calls': 2, 'wing sounds as covey flushed': 2, 'splash': 2, 'attack call': 2, 'begging call,juvenile': 2, 'Rattle Call': 2, 'thin call': 2, 'Anthropogenic background noise': 2, 'chatter calls': 2, 'flock': 2, 'flock calling': 2, 'aggression': 2, 'in flight': 2, 'flat calls': 2, 'soft calls': 2, 'chatter': 2, 'whistle': 2, 'grunt call': 2, 'wingflaps': 2, 'Wing beats': 2, 'conversational calling': 2, 'long calls': 2, 'bill snaps': 2, 'roosting call': 2, 'song at dawn': 2, 'Jirp': 2, 'noise of nesting colony': 2, 'songs': 2, 'alternative song': 2, 'zoo collection': 2, 'whisper song': 2, 'calls from ground': 2, 'interaction': 2, 'Courtship calls': 2, 'canto em voo': 2, 'alarm calls': 2, 'allarmcall': 2, 'Wing beat': 2, 'feeding call': 2, 'som do bater das asas. - sound of beating of wings.': 2, 'landing on water': 2, 'walking': 2, 'laughter': 2, 'Soundscape': 2, 'perched': 2, 'calls by perched pair': 2, 'flight calls from flock': 2, 'wing sounds in flight': 2, 'Wing sound': 2, 'Wing whir': 2, 'Flying': 2, 'call while strafing predator': 2, 'Tew': 2, 'Chewt': 2, 'mating': 2, 'wail calls': 2, 'Male and female duet': 2, 'short and long calls': 2, '"migrating bird"': 2, 'escape': 2, 'group in flight': 2, 'feeding calls': 2, 'Cheep': 2, 'wings flapping': 2, 'autumn': 2, 'Subsong': 2, 'long series of calls': 2, 'arched call': 2, 'ker-wee calls': 2, 'phrases': 2, 'Rattle': 2, 'Call from Birds at Roost': 2, 'sound from flushing': 2, 'mechanical tapping': 1, 'begging call (?)': 1, 'wing flutters': 1, 'calls by attacking male': 1, 'Alarmcalls': 1, 'juvenile type rattle': 1, 'Small group flying over.  Not recorded here during day': 1, 'advertisement call': 1, 'kip call': 1, 'chicks and adult in breeding colony': 1, 'wings beats': 1, 'human voices': 1, 'Insect sounds in background': 1, 'call,flight call,alarm call,aggressive  ...

# %%
from collections import Counter

# List of columns to analyze that contain lists as strings
columns_to_analyze = ['secondary_labels', 'type']

# Function to analyze each column with individual string components (case-insensitive)
def analyze_column_individual_case_insensitive(df, column_name):
    print(f"\nAnalyzing individual values within the column (case-insensitive): {column_name}")
    
    # Initialize a Counter to count each unique item across all entries
    item_counter = Counter()
    
    # Iterate over each entry in the column
    for entry in df[column_name].dropna():
        # Convert the string to a list and make each item lowercase
        items = [item.lower() for item in eval(entry)]  # Converts each item to lowercase
        # Update the counter with items in the list
        item_counter.update(items)
    
    # Print total unique items and counts for each
    unique_items = len(item_counter)
    print(f"Total number of unique items: {unique_items}")
    print(f"\nCount of occurrences for each unique item (case-insensitive):\n{item_counter}")

# Analyze each column in the list
for column in columns_to_analyze:
    analyze_column_individual_case_insensitive(filtered_metadata_df, column)
# Out:
# Analyzing individual values within the column (case-insensitive): secondary_labels
# Total number of unique items: 100
#
# Count of occurrences for each unique item (case-insensitive):
# Counter({'moudov': 127, 'houspa': 106, 'houfin': 100, 'mallar3': 82, 'gamqua': 75, 'apapan': 67, 'normoc': 62, 'norcar': 61, 'wesmea': 61, 'cangoo': 56, 'iiwi': 42, 'skylar': 41, 'warwhe1': 40, 'bknsti': 34, 'hawama': 32, 'gnwtea': 30, 'zebdov': 28, 'comgal1': 26, 'commyn': 24, 'dunlin': 22, 'arcter': 19, 'rinphe': 18, 'eurwig': 16, 'lesyel': 15, 'omao': 14, 'laugul': 14, 'redjun': 13, 'belkin1': 13, 'amewig': 13, 'rorpar': 13, 'leasan': 12, 'ribgul': 12, 'gadwal': 12, 'calqua': 12, 'norsho': 11, 'pibgre': 11, 'bkbplo': 11, 'lobdow': 11, 'sora': 9, 'spodov': 9, 'jabwar': 9, 'glwgul': 9, 'osprey': 8, 'rudtur': 8, 'norpin': 8, 'wiltur': 8, 'grbher3': 7, 'rocpig': 6, 'leater1': 5, 'snogoo': 5, 'caster1': 5, 'comwax': 5, 'bongul': 5, 'bcnher': 4, 'categr': 4, 'semplo': 4, 'cacgoo1': 4, 'fragul': 4, 'pecsan': 4, 'kauama': 3, 'aniani': 3, 'brant': 3, 'sposan': 3, 'gwfgoo': 3, 'brnowl': 3, 'whiter': 3, 'nutman': 3, 'oahama': 3, 'akiapo': 2, 'elepai': 2, 'hawcre': 2, 'saffin': 2, 'comsan': 2, 'hawgoo': 2, 'hawcoo': 2, 'sooshe': 2, 'buwtea': 2, 'sooter1': 2, 'sander': 2, 'hoomer': 2, 'refboo': 2, 'wessan': 2, 'redpha1': 2, 'pomjae': 2, 'blknod': 2, 'compea': 2, 'redava': 1, 'akepa1': 1, 'akikik': 1, 'blkfra': 1, 'brtcur': 1, 'brnnod': 1, 'rettro': 1, 'chukar': 1, 'bkwpet': 1, 'whfibi': 1, 'cintea': 1, 'lessca': 1, 'reccar': 1, 'yefcan': 1})
#
# Analyzing individual values within the column (case-insensitive): type
# Total number of unique items: 532
#
# Count of occurrences for each unique item (case-insensitive):
# Counter({'call': 6205, 'song': 3235, 'flight call': 2660, 'male': 1503, 'nocturnal flight call': 1337, 'adult': 1299, 'sex uncertain': 966, 'female': 739, 'alarm call': 723, 'juvenile': 408, 'life stage uncertain': 302, 'begging call': 282, 'uncertain': 56, 'calls': 40, 'subsong': 36, 'wingbeats': 34, 'mimicry/imitation': 30, 'aberrant': 26, 'wing noise': 26, 'hatchling or nestling': 25, 'wing beats': 25, 'social calls': 24, 'duet': 22, 'flight calls': 20, 'short calls': 19, 'flight song': 19, 'interaction calls': 16, 'wing-clapping': 16, 'various calls': 15, 'nocturnal call': 14, 'long call': 12, 'wings': 12, 'display': 12, 'nfc': 9, 'rolled calls': 9, 'nocturnal': 9, 'pair interaction calls': 9, 'whinny': 9, 'nocturnal flightcall': 8, 'pair contact calls': 8, 'dawn song': 7, 'contact calls': 7, 'distraction display': 7, '': 6, 'wing flapping': 6, 'flock calls': 6, 'nocturnal rooting site': 6, 'advertising call': 6, 'wing sounds': 5, 'low rattle': 5, 'interaction call': 5, 'flushed call': 5, 'wing whir': 5, 'excitement call': 5, 'screech': 5, 'short call': 5, 'take-off and flight calls': 4, 'anthropogenic': 4, 'bird in hand': 4, 'contact call': 4, 'single bird flying off': 4, 'social call': 4, 'canto': 4, 'song in flight': 4, 'autumn call': 4, 'wing flutter': 4, 'chatting': 4, 'peweep': 4, 'churts and sputters': 4, 'traffic': 3, 'night flight call': 3, 'rattle call': 3, 'series of calls': 3, 'aggression': 3, 'whistle': 3, 'whistle call': 3, 'display call': 3, 'chirp': 3, 'quiet-call': 3, 'landing on the water': 3, 'nest coo': 3, 'scold': 3, 'wingbeat': 3, 'feeding pair': 3, 'individual call': 3, 'per-weep': 3, 'phrases': 3, 'rattle': 3, 'whi-whee-whew': 2, 'female call': 2, 'male call': 2, 'courtship call': 2, 'attack': 2, 'no': 2, 'alarm and flight calls': 2, 'agitated calls': 2, 'calls in flight': 2, 'flock vocalizations': 2, 'various calls from a flock': 2, 'call,flight call,begging call': 2, 'single calls': 2, 'aggitated call': 2, 'whinny calls': 2, 'wing sounds as covey flushed': 2, 'wing flaps': 2, 'hissing': 2, 'splash': 2, 'attack call': 2, 'begging call,juvenile': 2, 'thin call': 2, 'anthropogenic background noise': 2, 'chatter calls': 2, 'flock': 2, 'flock calling': 2, 'in flight': 2, 'flat calls': 2, 'soft calls': 2, 'chatter': 2, 'grunt call': 2, 'wingflaps': 2, 'conversational calling': 2, 'long calls': 2, 'sneezing': 2, 'bill snaps': 2, 'roosting call': 2, 'song at dawn': 2, 'jirp': 2, 'noise of nesting colony': 2, 'songs': 2, 'alternative song': 2, 'zoo collection': 2, 'whisper song': 2, 'calls from ground': 2, 'interaction': 2, 'courtship calls': 2, 'canto em voo': 2, 'alarm calls': 2, 'allarmcall': 2, 'wing beat': 2, 'feeding call': 2, 'som do bater das asas. - sound of beating of wings.': 2, 'landing on water': 2, 'walking': 2, 'laughter': 2, 'soundscape': 2, 'perched': 2, 'calls by perched pair': 2, 'flight calls from flock': 2, 'wing sounds in flight': 2, 'wing whistle': 2, 'wing sound': 2, 'flying': 2, 'call while strafing predator': 2, 'tew': 2, 'chewt': 2, 'mating': 2, 'wail calls': 2, 'male and female duet': 2, 'short and long calls': 2, 'migrating bird': 2, '"migrating bird"': 2, 'escape': 2, 'group in flight': 2, 'feeding calls': 2, 'cheep': 2, 'wings flapping': 2, 'autumn': 2, 'long series of calls': 2, 'arched call': 2, 'ker-wee calls': 2, 'call from birds at roost': 2, 'sound from flushing': 2, 'mechanical tapping': 1, 'begging call (?)': 1, 'wing flutters': 1, 'calls by attacking male': 1, 'alarmcalls': 1, 'juvenile type rattle': 1, 'small group flying over.  not recorded here during day': 1, 'advertisement call': 1, 'kip call': 1, 'chicks and adult in breeding colony': 1, 'wings beats': 1, 'human voices': 1, 'insect sounds in background': 1, 'call,flight call,alarm call,aggressive call': 1, 'camera click': 1, 'chase calls': 1, 'ducks flushing off water': 1, 'high rattle': 1, 'aggressive interaction call': 1, 'migrating birds flying over': 1, 'nocturnal flight call.': 1, 'monotonous call': 1, 'un ...

# %%
from collections import Counter
import re
import pandas as pd

# List of columns to analyze
columns_to_analyze = ['secondary_labels', 'type']

# Function to analyze each column with individual string components, case-insensitive and space-insensitive
def analyze_column_individual_case_insensitive(df, column_name):
    print(f"\nAnalyzing individual values within the column (case-insensitive and space-insensitive): {column_name}")
    
    # Initialize a Counter to count each unique item across all entries
    item_counter = Counter()
    
    # Iterate over each entry in the column
    for entry in df[column_name].dropna():
        # Convert the string to a list, make each item lowercase, and remove spaces
        items = [re.sub(r'\s+', '', item.lower()) for item in eval(entry)]  # Lowercase and remove spaces
        # Update the counter with items in the list
        item_counter.update(items)
    
    # Print total unique items and counts for each
    unique_items = len(item_counter)
    print(f"Total number of unique items: {unique_items}")
    print(f"\nCount of occurrences for each unique item (case-insensitive and space-insensitive):\n{item_counter}")
    
    return item_counter

# Analyze the 'type' column
type_counts = analyze_column_individual_case_insensitive(filtered_metadata_df, 'type')

# Define noisy types to consider
noisy_terms = ['wing', 'wings', 'water', 'splash', 'rain', 'ground', 'background', 'noise', 'anthropogenic', 'traffic', 'street']

# Filter types that contain any of the noisy terms
noisy_types = [item for item in type_counts if any(term in item for term in noisy_terms)]

print("\nTypes identified as containing noise (including specified terms):")
print(noisy_types)

# Function to filter DataFrame by removing rows where all 'type' values match noisy types
def filter_noisy_rows(df, noisy_types):
    def has_only_noisy_types(type_list):
        # Clean and normalize type_list
        items = [re.sub(r'\s+', '', item.lower()) for item in eval(type_list)]
        # Check if all items are in noisy_types
        return all(item in noisy_types for item in items)
    
    # Filter the DataFrame
    filtered_df = df[~df['type'].apply(has_only_noisy_types)]
    
    return filtered_df

# Apply the filter to remove rows with only noisy types
filtered_metadata_df_cleaned = filter_noisy_rows(filtered_metadata_df, noisy_types)

# Display the total number of filtered samples
filtered_samples = len(filtered_metadata_df_cleaned)
print(f"Total number of samples without noisy types: {filtered_samples}")

# Analyze the 'type' column again for unique items after filtering
unique_items_after_filtering = analyze_column_individual_case_insensitive(filtered_metadata_df_cleaned, 'type')

# Display the filtered DataFrame without noisy types
print("\nFiltered DataFrame without noisy types:")
print(filtered_metadata_df_cleaned)
# Out:
# Analyzing individual values within the column (case-insensitive and space-insensitive): type
# Total number of unique items: 527
#
# Count of occurrences for each unique item (case-insensitive and space-insensitive):
# Counter({'call': 6205, 'song': 3235, 'flightcall': 2660, 'male': 1503, 'nocturnalflightcall': 1345, 'adult': 1299, 'sexuncertain': 966, 'female': 739, 'alarmcall': 723, 'juvenile': 408, 'lifestageuncertain': 302, 'beggingcall': 282, 'wingbeats': 59, 'uncertain': 56, 'calls': 40, 'subsong': 36, 'mimicry/imitation': 30, 'aberrant': 26, 'wingnoise': 26, 'hatchlingornestling': 25, 'socialcalls': 24, 'duet': 22, 'flightcalls': 20, 'shortcalls': 19, 'flightsong': 19, 'interactioncalls': 16, 'wing-clapping': 16, 'variouscalls': 15, 'nocturnalcall': 14, 'longcall': 12, 'wings': 12, 'display': 12, 'nfc': 9, 'rolledcalls': 9, 'nocturnal': 9, 'pairinteractioncalls': 9, 'whinny': 9, 'paircontactcalls': 8, 'dawnsong': 7, 'contactcalls': 7, 'distractiondisplay': 7, '': 6, 'wingflapping': 6, 'flockcalls': 6, 'nocturnalrootingsite': 6, 'advertisingcall': 6, 'wingsounds': 5, 'lowrattle': 5, 'interactioncall': 5, 'flushedcall': 5, 'wingwhir': 5, 'excitementcall': 5, 'screech': 5, 'wingbeat': 5, 'shortcall': 5, 'take-offandflightcalls': 4, 'anthropogenic': 4, 'birdinhand': 4, 'contactcall': 4, 'singlebirdflyingoff': 4, 'wingflaps': 4, 'socialcall': 4, 'canto': 4, 'songinflight': 4, 'autumncall': 4, 'wingflutter': 4, 'chatting': 4, 'peweep': 4, 'churtsandsputters': 4, 'traffic': 3, 'alarmcalls': 3, 'nightflightcall': 3, 'rattlecall': 3, 'seriesofcalls': 3, 'aggression': 3, 'whistle': 3, 'whistlecall': 3, 'displaycall': 3, 'chirp': 3, 'quiet-call': 3, 'landingonthewater': 3, 'nestcoo': 3, 'scold': 3, 'feedingpair': 3, 'individualcall': 3, 'per-weep': 3, 'phrases': 3, 'rattle': 3, 'whi-whee-whew': 2, 'femalecall': 2, 'malecall': 2, 'courtshipcall': 2, 'attack': 2, 'no': 2, 'alarmandflightcalls': 2, 'agitatedcalls': 2, 'callsinflight': 2, 'flockvocalizations': 2, 'variouscallsfromaflock': 2, 'call,flightcall,beggingcall': 2, 'singlecalls': 2, 'aggitatedcall': 2, 'whinnycalls': 2, 'wingsoundsascoveyflushed': 2, 'hissing': 2, 'splash': 2, 'attackcall': 2, 'beggingcall,juvenile': 2, 'thincall': 2, 'anthropogenicbackgroundnoise': 2, 'chattercalls': 2, 'flock': 2, 'flockcalling': 2, 'inflight': 2, 'flatcalls': 2, 'softcalls': 2, 'chatter': 2, 'gruntcall': 2, 'conversationalcalling': 2, 'longcalls': 2, 'sneezing': 2, 'billsnaps': 2, 'roostingcall': 2, 'songatdawn': 2, 'jirp': 2, 'noiseofnestingcolony': 2, 'songs': 2, 'alternativesong': 2, 'zoocollection': 2, 'whispersong': 2, 'callsfromground': 2, 'interaction': 2, 'courtshipcalls': 2, 'cantoemvoo': 2, 'allarmcall': 2, 'feedingcall': 2, 'somdobaterdasasas.-soundofbeatingofwings.': 2, 'landingonwater': 2, 'walking': 2, 'laughter': 2, 'soundscape': 2, 'perched': 2, 'callsbyperchedpair': 2, 'flightcallsfromflock': 2, 'wingsoundsinflight': 2, 'wingwhistle': 2, 'wingsound': 2, 'flying': 2, 'callwhilestrafingpredator': 2, 'tew': 2, 'chewt': 2, 'mating': 2, 'wailcalls': 2, 'maleandfemaleduet': 2, 'shortandlongcalls': 2, 'migratingbird': 2, '"migratingbird"': 2, 'escape': 2, 'groupinflight': 2, 'feedingcalls': 2, 'cheep': 2, 'wingsflapping': 2, 'autumn': 2, 'longseriesofcalls': 2, 'archedcall': 2, 'ker-weecalls': 2, 'callfrombirdsatroost': 2, 'soundfromflushing': 2, 'mechanicaltapping': 1, 'beggingcall(?)': 1, 'wingflutters': 1, 'callsbyattackingmale': 1, 'juveniletyperattle': 1, 'smallgroupflyingover.notrecordedhereduringday': 1, 'advertisementcall': 1, 'kipcall': 1, 'chicksandadultinbreedingcolony': 1, 'wingsbeats': 1, 'humanvoices': 1, 'insectsoundsinbackground': 1, 'call,flightcall,alarmcall,aggressivecall': 1, 'cameraclick': 1, 'chasecalls': 1, 'ducksflushingoffwater': 1, 'highrattle': 1, 'aggressiveinteractioncall': 1, 'migratingbirdsflyingover': 1, 'nocturnalflightcall.': 1, 'monotonouscall': 1, 'unusualcall': 1, 'rain': 1, '2calltypes': 1, '(?)alarmcalls': 1, 'scoldinflight': 1, 'contactoyllamadaalerta': 1, 'andcall': 1, 'contactsounds': 1, 'flockalarmingthentakingoff': 1, 'breathingsoundbeforediving': 1, 'begging': 1, 'clicks': 1, 'call,flightcall': 1, 'cleaking': 1, 'scream': 1, 'call,beggingcall': 1, ' ...
#
# Types identified as containing noise (including specified terms):
# ['traffic', 'wingflutters', 'wingsounds', 'wingsbeats', 'insectsoundsinbackground', 'ducksflushingoffwater', 'anthropogenic', 'rain', 'wings', 'trafficonfreeway', 'anthropogenic:', 'wingbeats', 'wingflapping', 'wingnoise', 'wingsinflight', 'wingsoundsascoveyflushed', 'wingwhir', 'wingflaps', 'wingbeatasflyingover', 'splash', 'waterdroplet', 'callsonwater', 'communicatingwhilefeedingontheground', 'anthropogenicbackgroundnoise', 'whistlesofduckwingsinflight', 'callfromthewater', 'noiseofwings', 'wingsplashes', 'noiseofnestingcolony', 'streettraffic', 'callsfromground', 'watersplashing', 'alarmfromwater', 'inclwingbeats', 'wingbeat', 'somdobaterdasasas.-soundofbeatingofwings.', 'landingonwater', 'birdisflyingoutofthewater(wingssound)', 'audiblewingbeats', 'flapwings', 'greylaggoosewingflapping', 'landingonthewater', 'wingwhirr', 'wingwhistles', 'wingsoundsinflight', 'wingwhistle', 'wingsound', 'flightwings', 'wingsoundsonflushingandflyingagain', 'wingnoisetakingflight', 'flyinginandlandingonwater', 'wingwhirofbirdflushing.', 'wing-noise', 'wingflutter', 'alarmclappingwithwings', 'flappingwings', 'winghits', 'beatswings', 'wingflappingdisplay', 'beatwings', 'wingbeat;cooing', 'feetnoise', 'anthropogenic&rain', 'soundfromwingclapping', 'wing-claps', 'mechanicalwingclapping', 'wingclapping', 'wingsflapping', 'wing-clapping', 'anthropogenic:thropogenic::rain', 'splashingsoundsas(ithink)twobirdschaseeachother', 'wingsclapping']
# Total number of samples without noisy types: 12608
#
# Analyzing individual values within the column (case-insensitive and space-insensitive): type
# Total number of unique items: 517
#
# Count of occurrences for each unique item (case-insensitive and space-insensitive):
# Counter({'call': 6205, 'song': 3235, 'flightcall': 2660, 'male': 1503, 'nocturnalflightcall': 1345, 'adult': 1299, 'sexuncertain': 966, 'female': 739, 'alarmcall': 723, 'juvenile': 408, 'lifestageuncertain': 302, 'beggingcall': 282, 'uncertain': 56, 'wingbeats': 43, 'calls': 40, 'subsong': 36, 'mimicry/imitation': 30, 'aberrant': 26, 'hatchlingornestling': 25, 'socialcalls': 24, 'wingnoise': 23, 'duet': 22, 'flightcalls': 20, 'shortcalls': 19, 'flightsong': 19, 'interactioncalls': 16, 'variouscalls': 15, 'nocturnalcall': 14, 'wing-clapping': 13, 'longcall': 12, 'display': 12, 'wings': 10, 'nfc': 9, 'rolledcalls': 9, 'nocturnal': 9, 'pairinteractioncalls': 9, 'whinny': 9, 'paircontactcalls': 8, 'dawnsong': 7, 'contactcalls': 7, 'distractiondisplay': 7, '': 6, 'wingflapping': 6, 'flockcalls': 6, 'nocturnalrootingsite': 6, 'advertisingcall': 6, 'wingsounds': 5, 'lowrattle': 5, 'interactioncall': 5, 'flushedcall': 5, 'wingwhir': 5, 'excitementcall': 5, 'screech': 5, 'wingbeat': 5, 'shortcall': 5, 'take-offandflightcalls': 4, 'anthropogenic': 4, 'birdinhand': 4, 'contactcall': 4, 'singlebirdflyingoff': 4, 'socialcall': 4, 'canto': 4, 'songinflight': 4, 'autumncall': 4, 'chatting': 4, 'peweep': 4, 'churtsandsputters': 4, 'traffic': 3, 'alarmcalls': 3, 'nightflightcall': 3, 'rattlecall': 3, 'seriesofcalls': 3, 'aggression': 3, 'whistle': 3, 'whistlecall': 3, 'displaycall': 3, 'chirp': 3, 'quiet-call': 3, 'landingonthewater': 3, 'nestcoo': 3, 'scold': 3, 'wingflutter': 3, 'feedingpair': 3, 'individualcall': 3, 'per-weep': 3, 'phrases': 3, 'rattle': 3, 'whi-whee-whew': 2, 'femalecall': 2, 'malecall': 2, 'courtshipcall': 2, 'attack': 2, 'no': 2, 'alarmandflightcalls': 2, 'agitatedcalls': 2, 'callsinflight': 2, 'flockvocalizations': 2, 'variouscallsfromaflock': 2, 'call,flightcall,beggingcall': 2, 'singlecalls': 2, 'aggitatedcall': 2, 'whinnycalls': 2, 'wingsoundsascoveyflushed': 2, 'wingflaps': 2, 'hissing': 2, 'splash': 2, 'attackcall': 2, 'beggingcall,juvenile': 2, 'thincall': 2, 'anthropogenicbackgroundnoise': 2, 'chattercalls': 2, 'flock': 2, 'flockcalling': 2, 'inflight': 2, 'flatcalls': 2, 'softcalls': 2, 'chatter': 2, 'gruntcall': 2, 'conversationalcalling': 2, 'longcalls': 2, 'sneezing': 2, 'billsnaps': 2, 'roostingcall': 2, 'songatdawn': 2, 'jirp': 2, 'noiseofnestingcolony': 2, 'songs': 2, 'alternativesong': 2, 'zoocollection': 2, 'whispersong': 2, 'interaction': 2, 'courtshipcalls': 2, 'cantoemvoo': 2, 'allarmcall': 2, 'feedingcall': 2, 'somdobaterdasasas.-soundofbeatingofwings.': 2, 'landingonwater': 2, 'walking': 2, 'laughter': 2, 'soundscape': 2, 'perched': 2, 'callsbyperchedpair': 2, 'flightcallsfromflock': 2, 'wingsoundsinflight': 2, 'wingwhistle': 2, 'wingsound': 2, 'flying': 2, 'callwhilestrafingpredator': 2, 'tew': 2, 'chewt': 2, 'mating': 2, 'wailcalls': 2, 'maleandfemaleduet': 2, 'shortandlongcalls': 2, 'migratingbird': 2, '"migratingbird"': 2, 'escape': 2, 'groupinflight': 2, 'feedingcalls': 2, 'cheep': 2, 'wingsflapping': 2, 'autumn': 2, 'longseriesofcalls': 2, 'archedcall': 2, 'ker-weecalls': 2, 'callfrombirdsatroost': 2, 'soundfromflushing': 2, 'mechanicaltapping': 1, 'beggingcall(?)': 1, 'wingflutters': 1, 'callsbyattackingmale': 1, 'juveniletyperattle': 1, 'smallgroupflyingover.notrecordedhereduringday': 1, 'advertisementcall': 1, 'kipcall': 1, 'chicksandadultinbreedingcolony': 1, 'wingsbeats': 1, 'humanvoices': 1, 'insectsoundsinbackground': 1, 'call,flightcall,alarmcall,aggressivecall': 1, 'cameraclick': 1, 'chasecalls': 1, 'ducksflushingoffwater': 1, 'highrattle': 1, 'aggressiveinteractioncall': 1, 'migratingbirdsflyingover': 1, 'nocturnalflightcall.': 1, 'monotonouscall': 1, 'unusualcall': 1, 'rain': 1, '2calltypes': 1, '(?)alarmcalls': 1, 'scoldinflight': 1, 'contactoyllamadaalerta': 1, 'andcall': 1, 'contactsounds': 1, 'flockalarmingthentakingoff': 1, 'breathingsoundbeforediving': 1, 'begging': 1, 'clicks': 1, 'call,flightcall': 1, 'cleaking': 1, 'scream': 1, 'call,beggingcall': 1, 'nãosei': 1, 'softcallb ...
#
# Filtered DataFrame without noisy types:
#       primary_label                secondary_labels  \
# 1           afrsil1  ['houspa', 'redava', 'zebdov']
# 2           afrsil1                              []
# 3           afrsil1                              []
# 4           afrsil1                              []
# 5           afrsil1                              []
# ...             ...                             ...
# 14844        zebdov                              []
# 14845        zebdov                              []
# 14846        zebdov                              []
# 14848        zebdov                              []
# 14849        zebdov                              []
#
#                                      type  latitude  longitude  \
# 1                                ['call']   19.8801  -155.7254
# 2                        ['call', 'song']   16.2901   -16.0321
# 3                  ['alarm call', 'call']   17.0922    54.2958
# 4                         ['flight call']   21.4581  -157.7252
# 5                         ['flight call']   21.4581  -157.7252
# ...                                   ...       ...        ...
# 14844                            ['song']   14.8920   105.8667
# 14845                            ['song']   18.2935    99.5007
# 14846                       ['uncertain']   13.9685   100.4153
# 14848  ['adult', 'sex uncertain', 'song']    1.4168   103.7287
# 14849  ['adult', 'call', 'sex uncertain']    1.4347   103.7043
#
#         scientific_name         common_name                    author  \
# 1       Euodice cantans  African Silverbill                  Dan Lane
# 2       Euodice cantans  African Silverbill                 Bram Piot
# 3       Euodice cantans  African Silverbill            Oscar Campbell
# 4       Euodice cantans  African Silverbill             Ross Gallardy
# 5       Euodice cantans  African Silverbill             Ross Gallardy
# ...                 ...                 ...                       ...
# 14844  Geopelia striata          Zebra Dove                 Bram Piot
# 14845  Geopelia striata          Zebra Dove  Somkiat Pakapinyo (Chai)
# 14846  Geopelia striata          Zebra Dove              Thaibirdspot
# 14848  Geopelia striata          Zebra Dove             Kim Chuah Lim
# 14849  Geopelia striata          Zebra Dove             Kim Chuah Lim
#
#                                                  license  rating   time  \
# 1      Creative Commons Attribution-NonCommercial-Sha...     3.5  08:30
# 2      Creative Commons Attribution-NonCommercial-Sha...     4.0  11:30
# 3      Creative Commons Attribution-NonCommercial-Sha...     4.0  11:00
# 4      Creative Commons Attribution-NonCommercial-Sha...     3.0  16:30
# 5      Creative Commons Attribution-NonCommercial-Sha...     4.0  16:30
# ...                                                  ...     ...    ...
# 14844  Creative Commons Attribution-NonCommercial-Sha...     3.5  06:45
# 14845  Creative Commons Attribution-NonCommercial-Sha...     5.0  08:00
# 14846  Creative Commons Attribution-NonCommercial-Sha...     5.0  11:30
# 14848  Creative Commons Attribution-NonCommercial-Sha...     4.0  08:00
# 14849  Creative Commons Attribution-NonCommercial-Sha...     4.0  09:00
#
#                                      url              filename
# 1      https://www.xeno-canto.org/175522  afrsil1/XC175522.ogg
# 2      https://www.xeno-canto.org/177993  afrsil1/XC177993.ogg
# 3      https://www.xeno-canto.org/205893  afrsil1/XC205893.ogg
# 4      https://www.xeno-canto.org/207431  afrsil1/XC207431.ogg
# 5      https://www.xeno-canto.org/207432  afrsil1/XC207432.ogg
# ...                                  ...                   ...
# 14844  https://www.xeno-canto.org/593996   zebdov/XC593996.ogg
# 14845  https://www.xeno-canto.org/598171   zebdov/XC598171.ogg
# 14846  https://www.xeno-canto.org/616403   zebdov/XC616403.ogg
# 14848  https://www.xeno-canto.org/642415   zebdov/XC642415.ogg
# 14849  https://www.xeno-canto.org/665873   zebdov/XC665873.ogg
#
# [12608 rows x 13 columns]
